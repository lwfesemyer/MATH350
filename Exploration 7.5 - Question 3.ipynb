# %%
#3a

import sympy as sp
t = sp.symbols('t')
x = sp.Function('x')(t)
f = 2*t*(1 + x ** 2)
ode = sp.Eq(sp.Derivative(x, t), f)
solution = sp.dsolve(ode, x, ics={x.subs(t, 1): sp.tan(1)})
print("Solution to equation with given initial conditions:", solution.rhs)
# Out:
# Solution to equation with given initial conditions: tan(t**2)

# %%
#3b

import matplotlib.pyplot as plt
import numpy as np
import math

numsteps = 10
stepwidth = 0.1
t = np.linspace(0, numsteps * stepwidth, numsteps + 1)
x = [0]


for i in range(numsteps):
    
    mk = 2*t[i]*(1+x[-1]**2)

    x.append(x[-1] + stepwidth * mk)
    
print("Predicted value of x(1):", x[-1])
print("Actual value of x(1):", np.tan(1**2))
print("Error:", np.abs(np.tan(1**2)-x[-1]))
erroreuler1 = np.abs(np.tan(1**2)-x[-1])

plt.plot(t, x, label = "Approximate tan(t^2)")
plt.plot(t,np.tan(t**2), label = "Exact tan(t^2)")
plt.title("tan(t^2) Approximation - Euler's Method, step size = 0.1")
plt.xlabel("Time t")
plt.ylabel("Function x(t)")
plt.legend()
plt.grid(True)
plt.savefig("3eulergraph1.png")
plt.show()
# Out:
# Predicted value of x(1): 1.123069650929991
# Actual value of x(1): 1.5574077246549023
# Error: 0.4343380737249114

# %%
#3c

import matplotlib.pyplot as plt
import numpy as np
import math

numsteps = 20
stepwidth = 0.05
t = np.linspace(0, numsteps * stepwidth, numsteps + 1)
x = [0]


for i in range(numsteps):
    
    mk = 2*t[i]*(1+x[-1]**2)

    x.append(x[-1] + stepwidth * mk)
    
print("Predicted value of x(1):", x[-1])
print("Actual value of x(1):", np.tan(1**2))
print("Error:", np.abs(np.tan(1**2)-x[-1]))
erroreuler2 = np.abs(np.tan(1**2)-x[-1])

plt.plot(t, x, label = "Approximate tan(t^2)")
plt.plot(t,np.tan(t**2), label = "Exact tan(t^2)")
plt.title("tan(t^2) Approximation - Euler's Method, step size = 0.05")
plt.xlabel("Time t")
plt.ylabel("Function x(t)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Predicted value of x(1): 1.2946800559580338
# Actual value of x(1): 1.5574077246549023
# Error: 0.2627276686968685

# %%
#3d

import matplotlib.pyplot as plt
import numpy as np
import math

numsteps = 100
stepwidth = 0.01
t = np.linspace(0, numsteps * stepwidth, numsteps + 1)
x = [0]


for i in range(numsteps):
    
    mk = 2*t[i]*(1+x[-1]**2)

    x.append(x[-1] + stepwidth * mk)
    
print("Predicted value of x(1):", x[-1])
print("Actual value of x(1):", np.tan(1**2))
print("Error:", np.abs(np.tan(1**2)-x[-1]))
erroreuler3 = np.abs(np.tan(1**2)-x[-1])

plt.plot(t, x, label = "Approximate tan(t^2)")
plt.plot(t,np.tan(t**2), label = "Exact tan(t^2)")
plt.title("tan(t^2) Approximation - Euler's Method, step size = 0.01")
plt.xlabel("Time t")
plt.ylabel("Function x(t)")
plt.legend()
plt.grid(True)
plt.savefig("3eulergraph3.png")
plt.show()
# Out:
# Predicted value of x(1): 1.4928572096958956
# Actual value of x(1): 1.5574077246549023
# Error: 0.06455051495900666

# %%
#3e(i)

import matplotlib.pyplot as plt
import numpy as np

numsteps = 10
stepwidth = 0.1
t = np.linspace(0, numsteps * stepwidth, numsteps + 1)
x = [0]

for i in range(numsteps):
    
    mk = 2*t[i]*(1+x[-1]**2)
    nk = 2*(t[i] + stepwidth)*(1+(x[-1] + stepwidth * mk)**2)

    x.append(x[-1] + stepwidth * (mk + nk) / 2)
    
print("Predicted value of x(1):", x[-1])
print("Actual value of x(1):", np.tan(1**2))
print("Error:", np.abs(np.tan(1**2)-x[-1]))
errorimprovedeuler1 = np.abs(np.tan(1**2)-x[-1])

plt.plot(t, x, label = "Approximate tan(t^2)")
plt.plot(t,np.tan(t**2), label = "Exact tan(t^2)")
plt.title("tan(t^2) Approximation - Improved Euler's Method, step size = 0.1")
plt.xlabel("Time t")
plt.ylabel("Function x(t)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Predicted value of x(1): 1.538703241498845
# Actual value of x(1): 1.5574077246549023
# Error: 0.018704483156057217

# %%
#3e(ii)

import matplotlib.pyplot as plt
import numpy as np

numsteps = 20
stepwidth = 0.05
t = np.linspace(0, numsteps * stepwidth, numsteps + 1)
x = [0]

for i in range(numsteps):
    
    mk = 2*t[i]*(1+x[-1]**2)
    nk = 2*(t[i] + stepwidth)*(1+(x[-1] + stepwidth * mk)**2)

    x.append(x[-1] + stepwidth * (mk + nk) / 2)
    
print("Predicted value of x(1):", x[-1])
print("Actual value of x(1):", np.tan(1**2))
print("Error:", np.abs(np.tan(1**2)-x[-1]))
errorimprovedeuler2 = np.abs(np.tan(1**2)-x[-1])

plt.plot(t, x, label = "Approximate tan(t^2 + pi/4)")
plt.plot(t,np.tan(t**2), label = "Exact tan(t^2 + pi/4)")
plt.title("tan(t^2 + pi/4) Approximation - Improved Euler's Method, step size = 0.05")
plt.xlabel("Time t")
plt.ylabel("Function x(t)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Predicted value of x(1): 1.552522013674331
# Actual value of x(1): 1.5574077246549023
# Error: 0.004885710980571334

# %%
#3e(iii)

import matplotlib.pyplot as plt
import numpy as np

numsteps = 100
stepwidth = 0.01
t = np.linspace(0, numsteps * stepwidth, numsteps + 1)
x = [0]

for i in range(numsteps):
    
    mk = 2*t[i]*(1+x[-1]**2)
    nk = 2*(t[i] + stepwidth)*(1+(x[-1] + stepwidth * mk)**2)

    x.append(x[-1] + stepwidth * (mk + nk) / 2)
    
print("Predicted value of x(1):", x[-1])
print("Actual value of x(1):", np.tan(1**2))
print("Error:", np.abs(np.tan(1**2)-x[-1]))
errorimprovedeuler3 = np.abs(np.tan(1**2)-x[-1])

plt.plot(t, x, label = "Approximate tan(t^2 + pi/4)")
plt.plot(t,np.tan(t**2), label = "Exact tan(t^2 + pi/4)")
plt.title("tan(t^2 + pi/4) Approximation - Improved Euler's Method, step size = 0.01")
plt.xlabel("Time t")
plt.ylabel("Function x(t)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Predicted value of x(1): 1.5572158759612453
# Actual value of x(1): 1.5574077246549023
# Error: 0.00019184869365695967

# %%
#3f(i)

import matplotlib.pyplot as plt
import numpy as np

numsteps = 10
stepwidth = 0.1
t = np.linspace(0, numsteps * stepwidth, numsteps + 1)
x = [0]

for i in range(numsteps):
    
    mk = 2*t[i]*(1+x[-1]**2)
    nk = 2*(t[i] + stepwidth / 2)*(1+(x[-1] + stepwidth * mk / 2)**2)
    pk = 2*(t[i] + stepwidth / 2)*(1+(x[-1] + stepwidth * nk / 2)**2)
    qk = 2*(t[i] + stepwidth)*(1+(x[-1] + stepwidth * pk)**2)

    x.append(x[-1] + stepwidth * (mk + 2 * nk + 2 * pk + qk) / 6)
    
print("Predicted value of x(1):", x[-1])
print("Actual value of x(1):", np.tan(1**2))
print("Error:", np.abs(np.tan(1**2)-x[-1]))
errorrungekatta1 = np.abs(np.tan(1**2)-x[-1])

plt.plot(t, x, label = "Approximate tan(t^2 + pi/4)")
plt.plot(t,np.tan(t**2), label = "Exact tan(t^2 + pi/4)")
plt.title("tan(t^2 + pi/4) Approximation - Runge-Katta Method, step size = 0.1")
plt.xlabel("Time t")
plt.ylabel("Function x(t)")
plt.legend()
plt.grid(True)
plt.savefig("3rungekattagraph1.png")
plt.show()
# Out:
# Predicted value of x(1): 1.5574275302059486
# Actual value of x(1): 1.5574077246549023
# Error: 1.980555104630355e-05

# %%
#3f(ii)

import matplotlib.pyplot as plt
import numpy as np

numsteps = 20
stepwidth = 0.05
t = np.linspace(0, numsteps * stepwidth, numsteps + 1)
x = [0]

for i in range(numsteps):
    
    mk = 2*t[i]*(1+x[-1]**2)
    nk = 2*(t[i] + stepwidth / 2)*(1+(x[-1] + stepwidth * mk / 2)**2)
    pk = 2*(t[i] + stepwidth / 2)*(1+(x[-1] + stepwidth * nk / 2)**2)
    qk = 2*(t[i] + stepwidth)*(1+(x[-1] + stepwidth * pk)**2)

    x.append(x[-1] + stepwidth * (mk + 2 * nk + 2 * pk + qk) / 6)
    
print("Predicted value of x(1):", x[-1])
print("Actual value of x(1):", np.tan(1**2))
print("Error:", np.abs(np.tan(1**2)-x[-1]))
errorrungekatta2 = np.abs(np.tan(1**2)-x[-1])

plt.plot(t, x, label = "Approximate tan(t^2 + pi/4)")
plt.plot(t,np.tan(t**2), label = "Exact tan(t^2 + pi/4)")
plt.title("tan(t^2 + pi/4) Approximation - Runge-Katta Method, step size = 0.05")
plt.xlabel("Time t")
plt.ylabel("Function x(t)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Predicted value of x(1): 1.5574124976117112
# Actual value of x(1): 1.5574077246549023
# Error: 4.772956808896112e-06

# %%
#3f(iii)

import matplotlib.pyplot as plt
import numpy as np

numsteps = 100
stepwidth = 0.01
t = np.linspace(0, numsteps * stepwidth, numsteps + 1)
x = [0]

for i in range(numsteps):
    
    mk = 2*t[i]*(1+x[-1]**2)
    nk = 2*(t[i] + stepwidth / 2)*(1+(x[-1] + stepwidth * mk / 2)**2)
    pk = 2*(t[i] + stepwidth / 2)*(1+(x[-1] + stepwidth * nk / 2)**2)
    qk = 2*(t[i] + stepwidth)*(1+(x[-1] + stepwidth * pk)**2)

    x.append(x[-1] + stepwidth * (mk + 2 * nk + 2 * pk + qk) / 6)
    
print("Predicted value of x(1):", x[-1])
print("Actual value of x(1):", np.tan(1**2))
print("Error:", np.abs(np.tan(1**2)-x[-1]))
errorrungekatta3 = np.abs(np.tan(1**2)-x[-1])

plt.plot(t, x, label = "Approximate tan(t^2 + pi/4)")
plt.plot(t,np.tan(t**2), label = "Exact tan(t^2 + pi/4)")
plt.title("tan(t^2 + pi/4) Approximation - Runge-Katta Method, step size = 0.01")
plt.xlabel("Time t")
plt.ylabel("Function x(t)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Predicted value of x(1): 1.557407739939002
# Actual value of x(1): 1.5574077246549023
# Error: 1.5284099763590575e-08

# %%
#3g

print("Errors for each Euler's method solution:")
print("Step size=0.1:", erroreuler1)
print("Step size=0.05:", erroreuler2)
print("Step size=0.01:", erroreuler3)
print()
print("Errors for each improved Euler's method solution:")
print("Step size=0.1:", errorimprovedeuler1)
print("Step size=0.05:", errorimprovedeuler2)
print("Step size=0.01:", errorimprovedeuler3)
print()
print("Errors for each Runge-Katta method solution:")
print("Step size=0.1:", errorrungekatta1)
print("Step size=0.05:", errorrungekatta2)
print("Step size=0.01:", errorrungekatta3)
# Out:
# Errors for each Euler's method solution:
# Step size=0.1: 0.4343380737249114
# Step size=0.05: 0.2627276686968685
# Step size=0.01: 0.06455051495900666
#
# Errors for each improved Euler's method solution:
# Step size=0.1: 0.018704483156057217
# Step size=0.05: 0.004885710980571334
# Step size=0.01: 0.00019184869365695967
#
# Errors for each Runge-Katta method solution:
# Step size=0.1: 1.980555104630355e-05
# Step size=0.05: 4.772956808896112e-06
# Step size=0.01: 1.5284099763590575e-08

# %%
#3h
print("Ratio of change in error for each Euler's method solution:")
print("From step size 0.1 to 0.05:", erroreuler1/erroreuler2)
print("From step size 0.05 to 0.01:", erroreuler2/erroreuler3)
print()
print("Ratio of change in error for each improved Euler's method solution:")
print("From step size 0.1 to 0.05:", errorimprovedeuler1/errorimprovedeuler2)
print("From step size 0.05 to 0.01:", errorimprovedeuler2/errorimprovedeuler3)
print()
print("Ratio of change in error for each Runge-Katta method solution:")
print("From step size 0.1 to 0.05:", errorrungekatta1/errorrungekatta2)
print("From step size 0.05 to 0.01:", errorrungekatta2/errorrungekatta3)
# Out:
# Ratio of change in error for each Euler's method solution:
# From step size 0.1 to 0.05: 1.6531874083884353
# From step size 0.05 to 0.01: 4.07010957021359
#
# Ratio of change in error for each improved Euler's method solution:
# From step size 0.1 to 0.05: 3.828405575040773
# From step size 0.05 to 0.01: 25.466480315510324
#
# Ratio of change in error for each Runge-Katta method solution:
# From step size 0.1 to 0.05: 4.1495349401420984
# From step size 0.05 to 0.01: 312.2824950584357
